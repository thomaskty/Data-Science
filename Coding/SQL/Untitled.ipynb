# %%
input - 1,00,000
output - one lakh
 
input - 3,94,563
output - three lakh ninety four thousand five hundred and sixty three

# %%
maps_ = {1:'one', 2:'two',}

n = len(str(_input))

# %%
def to_string(input_):
    input_ = list(input_)
    n = len(input_)
    position_values = [] 
    ones_position = 1 
    for i in range(n):
        while not ones_position>1

# %%
Hundred, zero ,
