# %%
def format_decorator(func):
    def wrapper(*args,**kwargs):
        print("Starting the formatting !")
        func(*args,**kwargs)
        print('Function has been executed !')
    return wrapper

@format_decorator
def hello_name(name):
    print('Function is executing : printing hello ',name)

hello_name('sample_input')
# Out:
# Starting the formatting !
# Function is executing : printing hello  sample_input
# Function has been executed !

# %%
# Puzzle 27: Find the first non-repeating character in a string
def first_non_repeating_character(s: str) -> str:
    # Your code here
    pass

# Puzzle 29: Find the longest increasing subsequence in a list
def longest_increasing_subsequence(lst: list) -> list:
    # Your code here
    pass

# Puzzle 30: Determine if a string contains only digits
def is_digit(s: str) -> bool:
    # Your code here
    pass

# Puzzle 31: Generate all permutations of a string
def string_permutations(s: str) -> list:
    # Your code here
    pass

# Puzzle 32: Find the minimum number of coins needed to make a certain amount
def min_coins(coins: list, amount: int) -> int:
    # Your code here
    pass

# Puzzle 33: Implement a function that returns the nth triangular number
def triangular_number(n: int) -> int:
    # Your code here
    pass

# Puzzle 34: Check if a binary tree is a binary search tree
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

def is_bst(root: TreeNode) -> bool:
    # Your code here
    pass

# Puzzle 35: Find the median of two sorted arrays
def find_median_sorted_arrays(nums1: list, nums2: list) -> float:
    # Your code here
    pass

# Puzzle 36: Find the length of the longest common subsequence of two strings
def longest_common_subsequence(s1: str, s2: str) -> int:
    # Your code here
    pass

# Puzzle 37: Implement a function to perform binary search
def binary_search(lst: list, target: int) -> int:
    # Your code here
    pass

# Puzzle 38: Check if a list contains duplicate elements
def contains_duplicates(lst: list) -> bool:
    # Your code here
    pass

# Puzzle 39: Find the longest substring without repeating characters
def longest_unique_substring(s: str) -> str:
    # Your code here
    pass

# Puzzle 40: Implement a function that returns the power set of a set
def power_set(s: set) -> list:
    # Your code here
    pass

# Puzzle 41: Find the longest palindromic substring in a string
def longest_palindromic_substring(s: str) -> str:
    # Your code here
    pass

# Puzzle 42: Check if a linked list has a cycle
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

def has_cycle(head: ListNode) -> bool:
    # Your code here
    pass

# Puzzle 43: Implement a function to add two binary numbers
def add_binary(a: str, b: str) -> str:
    # Your code here
    pass

# Puzzle 44: Find the majority element in a list
def majority_element(lst: list) -> int:
    # Your code here
    pass

# Puzzle 45: Convert a string to a zigzag pattern on a given number of rows
def zigzag_conversion(s: str, num_rows: int) -> str:
    # Your code here
    pass

# Puzzle 46: Implement a function to calculate the square root of a number using binary search
def sqrt(x: int) -> int:
    # Your code here
    pass

# Puzzle 47: Check if a number is an Armstrong number
def is_armstrong_number(n: int) -> bool:
    # Your code here
    pass

# Puzzle 48: Implement a function to find the first missing positive integer in an array
def first_missing_positive(nums: list) -> int:
    # Your code here
    pass

# Puzzle 49: Implement a function to remove duplicates from a sorted array
def remove_duplicates(nums: list) -> int:
    # Your code here
    pass

# Puzzle 50: Find the longest consecutive sequence in an array
def longest_consecutive_sequence(nums: list) -> int:
    # Your code here
    pass

# Puzzle 51: Implement a function to check if two binary trees are the same
def is_same_tree(p: TreeNode, q: TreeNode) -> bool:
    # Your code here
    pass

# Puzzle 52: Implement a function to reverse a linked list
def reverse_linked_list(head: ListNode) -> ListNode:
    # Your code here
    pass

# Puzzle 53: Implement a function to find the minimum depth of a binary tree
def min_depth(root: TreeNode) -> int:
    # Your code here
    pass

# Puzzle 54: Find the kth largest element in an array
def kth_largest_element(nums: list, k: int) -> int:
    # Your code here
    pass

# Puzzle 55: Implement a function to find the maximum product subarray
def max_product_subarray(nums: list) -> int:
    # Your code here
    pass

# Puzzle 56: Implement a function to find the shortest path in a grid
def shortest_path(grid: list) -> int:
    # Your code here
    pass

# Puzzle 57: Implement a function to check if a number is a happy number
def is_happy_number(n: int) -> bool:
    # Your code here
    pass

# Puzzle 58: Implement a function to find the missing number in an array
def find_missing_number(nums: list) -> int:
    # Your code here
    pass

# Puzzle 59: Implement a function to find the peak element in an array
def find_peak_element(nums: list) -> int:
    # Your code here
    pass

# Puzzle 60: Implement a function to check if a binary tree is symmetric
def is_symmetric(root: TreeNode) -> bool:
    # Your code here
    pass

# Puzzle 61: Implement a function to find the minimum path sum in a grid
def min_path_sum(grid: list) -> int:
    # Your code here
    pass

# Puzzle 62: Implement a function to find the number of islands in a grid
def num_islands(grid: list) -> int:
    # Your code here
    pass

# Puzzle 63: Implement a function to check if a number is a perfect square
def is_perfect_square(num: int) -> bool:
    # Your code here
    pass

# Puzzle 64: Implement a function to find the intersection of two arrays
def intersection_of_arrays(nums1: list, nums2: list) -> list:
    # Your code here
    pass

# Puzzle 65: Implement a function to find the first bad version in a list of versions
def first_bad_version(n: int) -> int:
    # Your code here
    pass

# Puzzle 66: Implement a function to check if a string is a valid palindrome
def valid_palindrome(s: str) -> bool:
    # Your code here
    pass

# Puzzle 67: Implement a function to find the k closest points to the origin
def k_closest_points(points: list, k: int) -> list:
    # Your code here
    pass

# Puzzle 68: Implement a function to find the minimum window substring in a string
def min_window_substring(s: str, t: str) -> str:
    # Your code here
    pass

# Puzzle 69: Implement a function to find the maximum width of a binary tree
def max_width_of_binary_tree(root: TreeNode) -> int:
    # Your code here
    pass

# Puzzle 70: Implement a function to find the largest rectangle in a histogram
def largest_rectangle_area(heights: list) -> int:
    # Your code here
    pass

# Puzzle 71: Implement a function to find the maximal square in a binary matrix
def maximal_square(matrix: list) -> int:
    # Your code here
    pass

# Puzzle 72: Implement a function to find the number of ways to climb stairs
def climb_stairs(n: int) -> int:
    # Your code here
    pass

# Puzzle 73: Implement a function to find the length of the longest valid parentheses substring
def longest_valid_parentheses(s: str) -> int:
    # Your code here
    pass

# Puzzle 74: Implement a function to find the number of ways to decode a string
def num_decodings(s: str) -> int:
    # Your code here
    pass

# Puzzle 75: Implement a function to find the minimum cost to climb stairs
def min_cost_climbing_stairs(cost: list) -> int:
    # Your code here
    pass

# Puzzle 76: Implement a function to find the maximum sum of a subarray with at most k elements
def max_subarray_sum_k_elements(nums: list, k: int) -> int:
    # Your code here
    pass

# Puzzle 77: Implement a function to find the minimum number of meeting rooms required
def min_meeting_rooms(intervals: list) -> int:
    # Your code here
    pass

# Puzzle 78: Implement a function to find the longest mountain in an array
def longest_mountain(nums: list) -> int:
    # Your code here
    pass

# Puzzle 79: Implement a function to find the number of distinct subsequences in a string
def num_distinct_subsequences(s: str, t: str) -> int:
    # Your code here
    pass

# Puzzle 80: Implement a function to find the maximum profit from buying and selling stocks
def max_profit(prices: list) -> int:
    # Your code here
    pass

# Puzzle 81: Implement a function to find the maximum length of a subarray with equal number of 0s and 1s
def find_max_length(nums: list) -> int:
    # Your code here
    pass

# Puzzle 82: Implement a function to find the minimum number of steps to reduce a number to zero
def min_steps_to_reduce_to_zero(n: int) -> int:
    # Your code here
    pass

# Puzzle 83: Implement a function to find the longest substring with at most k distinct characters
def length_of_longest_substring_k_distinct(s: str, k: int) -> int:
    # Your code here
    pass

# Puzzle 84: Implement a function to find the number of palindromic substrings in a string
def count_palindromic_substrings(s: str) -> int:
    # Your code here
    pass

# Puzzle 85: Implement a function to find the maximum product of three numbers in an array
def maximum_product_of_three(nums: list) -> int:
    # Your code here
    pass

# Puzzle 86: Implement a function to find the minimum window in a string that contains all the characters of another string
def min_window(s: str, t: str) -> str:
    # Your code here
    pass

# Puzzle 87: Implement a function to find the number of operations to make a string palindrome
def min_operations_to_make_palindrome(s: str) -> int:
    # Your code here
    pass

# Puzzle 88: Implement a function to find the minimum number of platforms required at a railway station
def find_platform(arrivals: list, departures: list) -> int:
    # Your code here
    pass

# Puzzle 89: Implement a function to find the minimum number of jumps to reach the end of an array
def min_jumps(nums: list) -> int:
    # Your code here
    pass

# Puzzle 90: Implement a function to find the largest sum of an hourglass in a 2D array
def max_hourglass_sum(grid: list) -> int:
    # Your code here
    pass

# Puzzle 91: Implement a function to find the maximum length of a subarray with positive product
def max_length_positive_product_subarray(nums: list) -> int:
    # Your code here
    pass

# Puzzle 92: Implement a function to find the minimum number of steps to make two strings anagrams
def min_steps_to_make_anagrams(s: str, t: str) -> int:
    # Your code here
    pass

# Puzzle 93: Implement a function to find the length of the longest increasing path in a matrix
def longest_increasing_path(matrix: list) -> int:
    # Your code here
    pass

# Puzzle 94: Implement a function to find the minimum number of operations to convert a string to another string
def min_operations_to_convert(s1: str, s2: str) -> int:
    # Your code here
    pass

# Puzzle 95: Implement a function to find the minimum number of swaps to make a string palindrome
def min_swaps_to_make_palindrome(s: str) -> int:
    # Your code here
    pass

# Puzzle 96: Implement a function to find the length of the longest arithmetic subsequence in an array
def longest_arithmetic_subsequence(nums: list) -> int:
    # Your code here
    pass

# Puzzle 97: Implement a function to find the minimum number of coins needed to make change for a given amount
def coin_change(coins: list, amount: int) -> int:
    # Your code here
    pass

# Puzzle 98: Implement a function to find the longest common prefix of an array of strings
def longest_common_prefix(strs: list) -> str:
    # Your code here
    pass

# Puzzle 99: Implement a function to find the number of ways to make change for a given amount
def change(amount: int, coins: list) -> int:
    # Your code here
    pass

# Puzzle 100: Implement a function to find the maximum sum of a subarray with at most two changes
def max_sum_with_two_changes(nums: list) -> int:
    # Your code here
    pass

# %%
class Stack:
    def __init__(self):
        self.items = [] 
    def is_empty(self):
        return self.items == [] 
    def push(self,item):
        self.items.append(item)  # append has o(1) 
    def pop(self):
        return self.items.pop()  # pop() has o(1)
    def peek(self):
        return self.items[len(self.items)-1] 
    def size (self):
        return len(self.items) 

# reversing string using stack 
def reverse_str(inpt_str):
    output_string = Stack() 
    for i in inpt_str:
        output_string.push(i) 

    final_string = ''
    for j in range(output_string.size()):
        final_string+= output_string.pop()
    print(final_string) 

# reversing the pop() and pushing operation 
# pop() will remove the first element 
# push() element will insert element at the first (beginning) position

class StackReverse:
    def __init__(self):
        self.items = []
    def is_empty(self):
        return self.items ==[] 
    def push(self,item):
        self.items.insert(0,item) 
    def pop(self):
        return self.items.pop(0) # pop(0) will remove the first item in the stack 
    def peek(self):
        return self.items[0] # peek() will return the first item 
    def size(self):
        return len(self.items) 
    
# implementing parenthesis checker function using stacks 
def par_checker(symbol_string):
    s = Stack()
    balanced = True 
    index = 0 
    while index<len(symbol_string) and balanced:
        symbol = symbol_string[index] 
        if symbol == "(":
            # adding the opening parenthesis to the stack 
            s.push(symbol)
        else:
            # if the stack is empty and we get a closing parenthesis then not balanced 
            if s.is_empty():
                balanced = False 
            else:
                # if the symbol is not opening parenthesis then pop() it from the stack if stack is not empty 
                s.pop() 
        index+=1 
    if balanced and s.is_empty():
        return True 
    else:
        return False 
    
        
# generalizing parenthesis checker using stacks 

def matches(open,close):
    opens = "([{"
    closes = ")]}"
    return opens.index(open) == closes.index(close) 


# creating a generalized parenthesis checker for "(),{},[]" 

def par_checker_gen(symbol_string):
    s = Stack() 
    balanced = True 
    index = 0 
    while index <len(symbol_string) and balanced:
        symbol = symbol_string[index] 
        if symbol in "([{":
            s.push(symbol) 
        else:
            if s.is_empty():
                balanced = False 
            else:
                # taking the opening bracket 
                top = s.pop() 
                # compare it with the first closing bracket 
                if not matches(top,symbol):
                    balanced = False 
        index+=1 
    if balanced and s.is_empty():
        return True 
    else:
        return False 


# has 2log(n) complexity 
def divide_by_2(dec_number):
    rem_stack = Stack() 
    while dec_number>0:
        rem = dec_number%2
        rem_stack.push(rem) 
        dec_number = dec_number//2 
    bin_string = ''
    while not rem_stack.is_empty():
        bin_string += str(rem_stack.pop())
    return bin_string


# more generalized version of converter wrt base 
def base_converter(dec_number,base):
    digits = '0123456789ABCDEF'
    rem_stack = Stack() 
    
    while dec_number>0:
        rem = dec_number%base 
        rem_stack.push(rem) 
        dec_number = dec_number//base 
        
    new_string = "" 
    while not rem_stack.is_empty():
        new_string+=digits[rem_stack.pop()]
    return new_string
